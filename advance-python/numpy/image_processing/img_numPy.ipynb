# %%
from PIL import Image
import numpy as np

# %%
image = Image.open("img.jfif")

print(f"Format: {image.format}")
print(f"Size: {image.size}")
print(f"Format Mode: {image.mode}")
# Out:
# Format: JPEG
# Size: (300, 168)
# Format Mode: RGB

# %%
numpydata = np.asanyarray(image) # convert image to numpy array
# numpydata.ndim
numpydata
# Out:
# array([[[164, 106,   9],
#         [142,  88,   0],
#         [107,  63,   0],
#         ...,
#         [ 45,  56,  39],
#         [ 55,  67,  43],
#         [ 53,  66,  40]],
#
#        [[152,  98,   0],
#         [141,  91,   0],
#         [126,  83,   0],
#         ...,
#         [ 37,  48,  31],
#         [ 48,  60,  36],
#         [ 50,  63,  37]],
#
#        [[142,  94,   0],
#         [140,  96,   0],
#         [142, 103,   8],
#         ...,
#         [ 43,  54,  37],
#         [ 50,  62,  40],
#         [ 45,  57,  33]],
#
#        ...,
#
#        [[169, 160, 153],
#         [169, 160, 153],
#         [170, 161, 154],
#         ...,
#         [179, 171, 160],
#         [178, 170, 159],
#         [178, 170, 159]],
#
#        [[169, 160, 153],
#         [169, 160, 153],
#         [169, 160, 153],
#         ...,
#         [179, 171, 160],
#         [178, 170, 159],
#         [178, 170, 159]],
#
#        [[169, 160, 153],
#         [169, 160, 153],
#         [169, 160, 153],
#         ...,
#         [179, 171, 160],
#         [178, 170, 159],
#         [178, 170, 159]]], shape=(168, 300, 3), dtype=uint8)

# %%
pilImage=Image.fromarray(numpydata)
pilImage
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
